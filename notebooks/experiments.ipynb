# %%
from binance.client import Client
import os

# %%
api_key = os.getenv('API_KEY')
secret_key = os.getenv('SECRET_KEY')

# %%
api_key
# Out:
# '7cawrnnRxTAMv1QrDTxFteAC0sc6UIhWGZ0qT8MSYXGFvLnln0e4FOw6DNVZtQJo'

# %%
client = Client(api_key, secret_key)
client.FUTURES_URL = "https://testnet.binancefuture.com/fapi"

# %%
symbol = "BTCUSDT"
side = "BUY"
order_type = "LIMIT"
quantity = 0.01
price = 50000

response = client.futures_create_order(
    symbol=symbol,
    side=side,
    type=order_type,
    quantity=quantity,
    price=price,
    timeInForce="GTC"
)

print(response)
# Out:
# {'orderId': 12800380502, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJb69fe66d6efcd58c481117', 'price': '50000.00', 'avgPrice': '0.00', 'origQty': '0.010', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'LIMIT', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'LIMIT', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1773456121215}
